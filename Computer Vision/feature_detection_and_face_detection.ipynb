# %%
import cv2
cv2.__version__
# Out:
# '4.7.0'

# %%
import numpy as np
import matplotlib.pyplot as plt

#import image
img_path = '/Users/devaggarwal/Documents/GitHub/Machine Learning/Computer Vision/'
img = cv2.imread(img_path + 'image3.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # convert to RGB
plt.axis('off')
plt.imshow(img)
